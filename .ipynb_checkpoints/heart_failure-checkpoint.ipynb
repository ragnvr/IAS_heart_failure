# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from sklearn.metrics import accuracy_score
'''
sujet: [classification] Déterminer si une personne atteintes de maladies cardiovasculaire  va  
mourir ou pas en fonction de ses antécédent (fumeur ou pas, diabète ou pas, hyper-tension ou pas...)

'time' très corrélé avec 'DEATH_EVENT' => a supprimer 

11 features => 2 labels : DEAD / SURVIVE
'''

dataset = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
dataset.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
dataset.head(300)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
dataset.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
dataset.hist(bins=10,figsize=(12,10),grid=False);

# %%
dataset.info()  #aucune valeur null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
dataset.shape
# Out:
# (299, 13)

# %%
dataset.describe(include = 'all') # age: Age
                                # anaemia: Decrease of red blood cells or hemoglobin (boolean)
                                # creatinine_phosphokinase : Level of the CPK enzyme in the blood (mcg/L)
                                # diabetes : If the patient has diabetes (boolean)
                                # ejection_fraction : Percentage of blood leaving the heart at each contraction (percentage)
                                # high_blood_pressure : If the patient has hypertension (boolean)
                                # platelets : Platelets in the blood (kiloplatelets/mL)
                                # serum_creatinine : Level of serum creatinine in the blood (mg/dL)
                                # serum_sodium : Level of serum sodium in the blood (mEq/L)
                                # sex : Woman or man (binary)
                                # smoking : If the patient smokes or not (boolean)
                                # time : Follow-up period (days)
                                # DEATH_EVENT : If the patient deceased during the follow-up period (boolean)
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
#Probablement besoin d'uniformiser les données car il y a des ratio de 0 à 1 et des valeurs énormes à coté

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dataset.corr(), vmin=-1, annot=True);
'''
'time' et 'death_event'  :  tres corrélé
'sex' et 'smoking'       :  corrélé

'''
## mais 'sex' et 'smoking' reste une information importante car 
## fumer peut avoir des conséquences sur la santé d'un patient
# Out:
# "\n'time' et 'death_event'  :  tres corrélé\n'sex' et 'smoking'       :  corrélé\n\n"

# %%
#'TIME' corréleé avec 'DEATH_EVENT' ?  => verifions  
le_temps = []
score_temps = []
for i in range(dataset['time'].min(),dataset['time'].max()+1):
    score_res= 100*np.mean((dataset['time'].to_numpy() < i) == dataset['DEATH_EVENT'].to_numpy())
    print('%i : %.2f'%(i,score_res))
    le_temps.append(i)
    score_temps.append(score_res)
# Out:
# 4 : 67.89
# 5 : 68.23
# 6 : 68.23
# 7 : 68.56
# 8 : 69.23
# 9 : 69.90
# 10 : 69.90
# 11 : 71.91
# 12 : 72.58
# 13 : 72.24
# 14 : 72.58
# 15 : 73.24
# 16 : 73.91
# 17 : 73.58
# 18 : 73.58
# 19 : 73.58
# 20 : 73.58
# 21 : 74.25
# 22 : 74.25
# 23 : 73.91
# 24 : 74.58
# 25 : 74.92
# 26 : 74.92
# 27 : 75.92
# 28 : 76.25
# 29 : 76.92
# 30 : 76.92
# 31 : 77.93
# 32 : 78.26
# 33 : 78.60
# 34 : 78.93
# 35 : 78.93
# 36 : 79.26
# 37 : 79.26
# 38 : 79.26
# 39 : 79.60
# 40 : 79.60
# 41 : 79.93
# 42 : 80.27
# 43 : 80.60
# 44 : 81.61
# 45 : 81.94
# 46 : 82.27
# 47 : 82.27
# 48 : 82.27
# 49 : 82.27
# 50 : 82.27
# 51 : 82.61
# 52 : 82.61
# 53 : 82.61
# 54 : 82.61
# 55 : 81.94
# 56 : 82.27
# 57 : 82.27
# 58 : 82.27
# 59 : 82.27
# 60 : 82.61
# 61 : 82.94
# 62 : 83.28
# 63 : 83.28
# 64 : 82.94
# 65 : 83.28
# 66 : 83.95
# 67 : 84.28
# 68 : 84.62
# 69 : 84.28
# 70 : 84.28
# 71 : 84.28
# 72 : 83.95
# 73 : 83.95
# 74 : 84.62
# 75 : 83.28
# 76 : 82.94
# 77 : 82.61
# 78 : 82.94
# 79 : 82.94
# 80 : 81.27
# 81 : 80.60
# 82 : 80.60
# 83 : 80.60
# 84 : 79.60
# 85 : 79.60
# 86 : 78.93
# 87 : 78.60
# 88 : 76.92
# 89 : 75.92
# 90 : 75.92
# 91 : 75.92
# 92 : 75.25
# 93 : 75.25
# 94 : 75.25
# 95 : 74.25
# 96 : 73.24
# 97 : 73.58
# 98 : 73.24
# 99 : 73.24
# 100 : 73.24
# 101 : 73.58
# 102 : 73.58
# 103 : 73.58
# 104 : 73.58
# 105 : 72.91
# 106 : 72.58
# 107 : 72.24
# 108 : 70.23
# 109 : 69.23
# 110 : 68.90
# 111 : 68.56
# 112 : 68.90
# 113 : 68.23
# 114 : 68.23
# 115 : 68.23
# 116 : 68.23
# 117 : 68.23
# 118 : 67.89
# 119 : 67.56
# 120 : 67.22
# 121 : 65.89
# 122 : 64.55
# 123 : 64.55
# 124 : 64.21
# 125 : 64.21
# 126 : 64.21
# 127 : 64.55
# 128 : 64.55
# 129 : 64.55
# 130 : 64.88
# 131 : 65.22
# 132 : 65.22
# 133 : 65.22
# 134 : 65.22
# 135 : 64.88
# 136 : 65.22
# 137 : 65.22
# 138 : 65.22
# 139 : 65.22
# 140 : 65.22
# 141 : 64.88
# 142 : 64.88
# 143 : 64.88
# 144 : 64.88
# 145 : 64.88
# 146 : 64.21
# 147 : 62.54
# 148 : 61.20
# 149 : 60.87
# 150 : 60.87
# 151 : 61.20
# 152 : 61.20
# 153 : 61.20
# 154 : 61.20
# 155 : 61.54
# 156 : 61.54
# 157 : 61.54
# 158 : 61.54
# 159 : 61.54
# 160 : 61.54
# 161 : 61.54
# 162 : 61.54
# 163 : 61.87
# 164 : 61.87
# 165 : 61.87
# 166 : 61.87
# 167 : 61.87
# 168 : 61.87
# 169 : 61.87
# 170 : 61.87
# 171 : 62.21
# 172 : 62.54
# 173 : 62.88
# 174 : 62.88
# 175 : 61.87
# 176 : 61.54
# 177 : 61.54
# 178 : 61.54
# 179 : 61.54
# 180 : 61.54
# 181 : 61.87
# 182 : 61.87
# 183 : 61.87
# 184 : 61.87
# 185 : 61.87
# 186 : 61.54
# 187 : 59.53
# 188 : 57.19
# 189 : 56.86
# 190 : 56.86
# 191 : 56.86
# 192 : 56.86
# 193 : 56.19
# 194 : 56.52
# 195 : 56.19
# 196 : 55.85
# 197 : 55.85
# 198 : 55.18
# 199 : 55.52
# 200 : 55.52
# 201 : 55.18
# 202 : 54.52
# 203 : 54.52
# 204 : 54.52
# 205 : 54.52
# 206 : 53.51
# 207 : 53.18
# 208 : 52.84
# 209 : 52.51
# 210 : 50.84
# 211 : 50.17
# 212 : 49.83
# 213 : 48.83
# 214 : 47.83
# 215 : 46.82
# 216 : 45.48
# 217 : 45.15
# 218 : 45.15
# 219 : 45.15
# 220 : 45.15
# 221 : 44.82
# 222 : 44.82
# 223 : 44.82
# 224 : 44.82
# 225 : 44.82
# 226 : 44.82
# 227 : 44.82
# 228 : 44.82
# 229 : 44.82
# 230 : 44.82
# 231 : 44.15
# 232 : 43.81
# 233 : 43.81
# 234 : 43.14
# 235 : 43.14
# 236 : 43.48
# 237 : 43.48
# 238 : 42.81
# 239 : 42.81
# 240 : 42.81
# 241 : 42.47
# 242 : 42.81
# 243 : 42.81
# 244 : 42.81
# 245 : 41.14
# 246 : 39.46
# 247 : 38.46
# 248 : 38.13
# 249 : 38.13
# 250 : 38.13
# 251 : 35.79
# 252 : 35.79
# 253 : 35.79
# 254 : 35.79
# 255 : 35.79
# 256 : 35.79
# 257 : 35.12
# 258 : 34.78
# 259 : 34.11
# 260 : 34.11
# 261 : 34.11
# 262 : 34.11
# 263 : 34.11
# 264 : 34.11
# 265 : 34.11
# 266 : 34.11
# 267 : 34.11
# 268 : 34.11
# 269 : 34.11
# 270 : 34.11
# 271 : 33.44
# 272 : 33.11
# 273 : 33.11
# 274 : 33.11
# 275 : 33.11
# 276 : 33.11
# 277 : 33.11
# 278 : 33.11
# 279 : 32.78
# 280 : 32.78
# 281 : 32.44
# 282 : 32.44
# 283 : 32.44
# 284 : 32.44
# 285 : 32.44

# %%
plt.plot(le_temps,score_temps)
## on voit la courbe atteint un pic à 84% ce qui signifie que la majorité 
## des patients sont mort avant le 'time' (jour) 74.
## le feature 'time' et bien corrélé à notre label 'DEATH_EVENT'
## De plus on ne cheche pas à prédire le jour où le patient est mort
## mais prédire si il va mourir où pas

# %%
# On decide donc de supprimer time 

dataset.drop('time', axis=1, inplace=True)

dataset.head(5)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  DEATH_EVENT
# 0        0            1
# 1        0            1
# 2        1            1
# 3        0            1
# 4        0            1

# %% [markdown]
# <h2> L'AGE un indicateur de mort </h2>

# %%
dataset['age']= dataset['age'].astype(int) # convertit age floattant en int
mort_l=dataset["DEATH_EVENT"]
age_l = dataset["age"]  
sex_l = dataset["sex"]
diabete_l = dataset["diabetes"]
anemie_l = dataset["anaemia"]
#dataset['age']

# %%
l_age_res = []
l_moy_res= []
for i in range(age_l.min(), age_l.max()): 
    if(np.sum(dataset['age'] ==i) !=0): # prend pas en compte valeur NaN
        age = dataset['age'] ==i
        moy = round(100*np.mean(dataset['DEATH_EVENT'][age]))
        l_age_res.append(i)
        l_moy_res.append(moy)
        #print("age = ", i ," score Mort= ", moy, "nb pers = ", np.sum(age))
plt.plot(l_age_res, l_moy_res)

## pas vraiment significatif car le nombre de patient
## n'est pas le meme pour deux ages différents
#ex: 2 patients qui ont 48 ans et les 2 sont mort
##  vs 35 patients pour 60 ans

# %% [markdown]
# <h2> Verifions si le SEX un indicateur de mort </h2>

# %%
homme = dataset['sex']==1
femme = dataset['sex'] ==0
homme_morts = dataset['DEATH_EVENT'][homme] == 1
femme_morts= dataset['DEATH_EVENT'][femme] == 1
homme_vivants = dataset['DEATH_EVENT'][homme] == 0
femme_vivantes = dataset['DEATH_EVENT'][femme] == 0
#print("nb Homme =", np.sum(homme) ,"nb Femme = ", np.sum(femme))
#print("nb Homme morts =", np.sum(homme_morts) ,"nb Femme morts = ", np.sum(femme_morts))

#print("nb Homme =", np.sum(homme) ,"nb Femme = ", np.sum(femme))
#print("nb Homme morts =", np.sum(homme_morts) ,"nb Femme morts = ", np.sum(femme_morts))

# %%
#petite représentation
labels = 'homme en vie', 'homme_dead', 'femme en vie', 'femme_dead' 
sizes = [np.sum(homme_vivants), np.sum(homme_morts),np.sum(femme_vivantes),np.sum(femme_morts)]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')

plt.show()

#A commenter

# %% [markdown]
# <h2> Verifions si le DIABETE un indicateur de mort </h2>

# %%
les_diabetiques = dataset['diabetes'] == 1
les_non_diabetiques = dataset['diabetes'] == 0
diabetes_mort = dataset['DEATH_EVENT'][les_diabetiques]  == 1 
non_diabetique_mort = dataset['DEATH_EVENT'][les_non_diabetiques]  == 1
diabetes_vivant = dataset['DEATH_EVENT'][les_diabetiques]  == 0
non_diabetique_vivant = dataset['DEATH_EVENT'][les_non_diabetiques]  == 0

# %%
#petite représentation
labels = 'diabetiques vivants', 'non-diabetiques vivants', 'non diabetiques mort' , 'diabetiques mort'
sizes = [np.sum(diabetes_vivant), np.sum(non_diabetique_vivant),np.sum(non_diabetique_mort),np.sum(diabetes_mort)]

plt.pie(sizes, labels=labels,  autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')

plt.show()

#A commenter
np.sum(diabetes_vivant)/np.sum(diabetes_mort),np.sum(non_diabetique_vivant)/ np.sum(non_diabetique_mort)
# Out:
# (2.125, 2.107142857142857)

# %% [markdown]
# <h2> Verifions si l'anémie est indicateur de mort</h2>

# %%
anemie_true = dataset["anaemia"] ==1
anemie_false = dataset["anaemia"]  ==0
anemia_mort = dataset['DEATH_EVENT'][anemie_true] == 1
non_anemia_mort = dataset['DEATH_EVENT'][anemie_false] == 1
anemia_vivant = dataset['DEATH_EVENT'][anemie_true] == 0
non_anemia_vivant = dataset['DEATH_EVENT'][anemie_false] == 0

# %%
#petite représentation
labels = 'atteint anemie', 'anemie mort', 'non-atteint','non anemie mort'
sizes = [np.sum(anemia_vivant), np.sum(anemia_mort),np.sum(non_anemia_vivant),np.sum(non_anemia_mort)]

plt.pie(sizes, labels=labels,  autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')

plt.show()

#A commenter
## 11.6 % des 32.7% sont mort atteint d'anemie
## 12.7 % des 43.0% sont mort non atteint d'anemie
np.sum(anemia_vivant)/np.sum(anemia_mort),np.sum(non_anemia_vivant)/ np.sum(non_anemia_mort)
# Out:
# (1.8043478260869565, 2.4)

# %% [markdown]
# <h2>Autre visualisation à faire </h2>

# %%
#idee
print("------Hommes qui fummes ------")
print("" ,dataset["smoking"][dataset["sex"] == 1].value_counts(normalize = True)[1]*100)

print("------Femmes qui fumme------")
print("" ,dataset["smoking"][dataset["sex"] == 0].value_counts(normalize = True)[1]*100)
# Out:
# ------Hommes qui fummes ------
#  47.42268041237113
# ------Femmes qui fumme------
#  3.8095238095238098

# %% [markdown]
# <h2>Normalisation/Standardisation (standardisation) , faire la normalisation </h2>

# %%
#StandardScaler or MinMaxScaler

# %%
scaled_features = dataset.copy()
col_names = ['age', 'creatinine_phosphokinase', 'ejection_fraction' ,'platelets' ,'serum_creatinine','serum_sodium']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
scaled_features[col_names] = features
scaled_features.head()
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  1.193302        0                  0.000166         0          -1.530560
# 1 -0.490896        0                  7.514640         0          -0.007077
# 2  0.351203        0                 -0.449939         0          -1.530560
# 3 -0.911945        1                 -0.486071         0          -1.530560
# 4  0.351203        1                 -0.435486         1          -1.530560
#
#    high_blood_pressure     platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  1.681648e-02          0.490057     -1.504036    1
# 1                    0  7.535660e-09         -0.284552     -0.141976    1
# 2                    0 -1.038073e+00         -0.090900     -1.731046    1
# 3                    0 -5.464741e-01          0.490057      0.085034    1
# 4                    0  6.517986e-01          1.264666     -4.682176    0
#
#    smoking  DEATH_EVENT
# 0        0            1
# 1        0            1
# 2        1            1
# 3        0            1
# 4        0            1

# %%
dataset.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   75        0                       582         0                 20
# 1   55        0                      7861         0                 38
# 2   65        0                       146         0                 20
# 3   50        1                       111         0                 20
# 4   65        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  DEATH_EVENT
# 0        0            1
# 1        0            1
# 2        1            1
# 3        0            1
# 4        0            1

# %%
features= scaled_features.columns[:-1] # toutes les colonnes sauf la derniere
label = scaled_features.columns[-1] #derniere colonnes 'DEATH EVENT'

X = scaled_features[features].values
y = scaled_features[label].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state =5)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#scaler.fit(x_train)  # Don't cheat - fit only on training data   ##SKLEARN 
#x_train = scaler.transform(x_train)
#x_test = scaler.transform(x_test) 

## on standardise sur l'ensemble ou bien que sur les données qui ont une dim diff des données binaires ??
print(x_train)
# Out:
# [[-0.91194532  0.          1.30505581 ...  0.08503384  1.
#    1.        ]
#  [ 1.53014173  1.         -0.54388259 ... -0.82300614  1.
#    0.        ]
#  [-1.5856245   0.         -0.53459144 ...  0.76606383  1.
#    0.        ]
#  ...
#  [ 0.35120315  1.         -0.4840063  ...  0.76606383  0.
#    0.        ]
#  [-1.7540443   0.         -0.34876849 ...  0.76606383  0.
#    0.        ]
#  [-1.7540443   1.         -0.4963945  ...  0.99307383  0.
#    0.        ]]

# %%
#on fixe 
#loss = 'log'
#penalite =  l2'
#random_state pour la reproductibilité du résultat : on choissi 5 

model=  SGDClassifier(loss='log', penalty='l2', random_state=5)
model.fit(x_train,y_train)
print(model.score(x_train,y_train))  ## on pas d'overfitting sinon on aurait eu 100%
# Out:
# 0.5454545454545454

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h2>  logistic regression vs linear svm (hors sujet) </h2>

# %%
##########
    ## SGDClassifier avec une fonction cout 'log' est equivalent à la fonction logistic regression
 ##source sklearn

model=  SGDClassifier(loss='log', penalty='l2', random_state=5)  
model.fit(x_train,y_train)
                                
predY = model.predict(x_test)
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predY)))
# Out:
# Accuracy: 0.53

# %%
    ## SGDClassifier avec une fonction cout 'hinge' est equivalent à la fonction SVM


model=  SGDClassifier(loss='hinge', penalty='l2' ,random_state=5)  ## fonction cout hinge ~~~   linear svm  ##source sklearn
model.fit(x_train,y_train)
                                
predY = model.predict(x_test)
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predY)))
# Out:
# Accuracy: 0.68

# %%
dataset.head(5)
# Out:
#    age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   75        0                       582         0                 20
# 1   55        0                      7861         0                 38
# 2   65        0                       146         0                 20
# 3   50        1                       111         0                 20
# 4   65        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  DEATH_EVENT
# 0        0            1
# 1        0            1
# 2        1            1
# 3        0            1
# 4        0            1

# %% [markdown]
# <h1> penalité  L2 comparer score avec fonction cout </h1>
# #l2 empeche l'overfitting

# %% [markdown]
# <h2> Fonction coût / score </h2>

# %%
#recherche du meilleur random_state
score_model = []
loss_name =[]

loss_l = ['hinge','log', 'modified_huber', 'squared_hinge', 'perceptron','squared_loss', 'huber', 'epsilon_insensitive','squared_epsilon_insensitive']    
for i in loss_l:
    model_1 = SGDClassifier(loss=i, penalty='l2' , random_state=5)
    model_1.fit(x_train,y_train)
    scoreFinal =  model_1.score(x_train,y_train)
    print("loss :  " , i , " score = ",scoreFinal)
    loss_name.append(i)
    score_model.append(scoreFinal)
# Out:
# loss :   hinge  score =  0.7511961722488039
# loss :   log  score =  0.5454545454545454
# loss :   modified_huber  score =  0.722488038277512
# loss :   squared_hinge  score =  0.6794258373205742
# loss :   perceptron  score =  0.7272727272727273
# loss :   squared_loss  score =  0.569377990430622
# loss :   huber  score =  0.6267942583732058
# loss :   epsilon_insensitive  score =  0.5311004784688995
# loss :   squared_epsilon_insensitive  score =  0.4784688995215311

# %%
plt.figure(1, figsize=(16, 6))
plt.plot(loss_name,score_model)

# %%
scoreMaxi_index = score_model.index(max(score_model))
lossWithMaxScore = loss_name[scoreMaxi_index]
scoreMaxi = max(score_model)
print("score = ", scoreMaxi,  " Loss name = ", lossWithMaxScore)
# Out:
# score =  0.6888888888888889  Loss name =  perceptron

# %%
## hinge est la fonction coût qui maximise notre score pour une penalité l2

# %% [markdown]
# <h1> penalité  L1 comparer score avec fonction cout </h1>

# %% [markdown]
# <h2> Fonction coût / score </h2>

# %%
#recherche du meilleur random_state
score_model = []
loss_name =[]

loss_l = ['hinge','log', 'modified_huber', 'squared_hinge', 'perceptron','squared_loss', 'huber', 'epsilon_insensitive','squared_epsilon_insensitive']    
for i in loss_l:
    model_1 = SGDClassifier(loss=i, penalty='l1' , random_state=5)
    model_1.fit(x_train,y_train)
    scoreFinal =  model_1.score(x_test,y_test)
    print("loss :  " , i , " score = ",scoreFinal)
    loss_name.append(i)
    score_model.append(scoreFinal)
# Out:
# loss :   hinge  score =  0.7111111111111111
# loss :   log  score =  0.7111111111111111
# loss :   modified_huber  score =  0.6777777777777778
# loss :   squared_hinge  score =  0.6
# loss :   perceptron  score =  0.7555555555555555
# loss :   squared_loss  score =  0.37777777777777777
# loss :   huber  score =  0.6888888888888889
# loss :   epsilon_insensitive  score =  0.5111111111111111
# loss :   squared_epsilon_insensitive  score =  0.4

# %%
plt.figure(1, figsize=(16, 6))
plt.plot(loss_name,score_model)

# %%
scoreMaxi_index = score_model.index(max(score_model))
lossWithMaxScore = loss_name[scoreMaxi_index]
scoreMaxi = max(score_model)
print("score = ", scoreMaxi,  " Loss name = ", lossWithMaxScore)
# Out:
# score =  0.7555555555555555  Loss name =  perceptron

# %%
## epsilon_insensitive est la fonction coût qui maximise notre score pour une penalité l1

# %% [markdown]
# <h2>Cross-validation (recherche du meilleurs alpha) </h2>

# %%
monScoring = 'accuracy'  #metrique de score classification

# %%
score_cv_l = []
alphaVal=[]
#alpha_values = np.logspace(-7,1, num=15)

alpha_values = np.arange(0.01,0.4,0.001)
for alpha_l in alpha_values:
    #print("Alpha = ", alpha_l)
    model_cv=  SGDClassifier(penalty='l2', alpha=alpha_l , random_state=5 ,loss='perceptron')
    kfold = KFold(n_splits=10)
    cv_results = cross_val_score(model_cv, x_train, y_train, cv=kfold, scoring=monScoring)
    msg = "%s %f, erreur quad. moyenne: %f +/- (%f)" % ("regression lineaire:, alpha=",alpha_l, cv_results.mean(), cv_results.std())
        
    print(msg)
    score_cv_l.append((cv_results.mean())*100)
    alphaVal.append(alpha_l)
# Out:
# regression lineaire:, alpha= 0.010000, erreur quad. moyenne: 0.669524 +/- (0.112611)
# regression lineaire:, alpha= 0.011000, erreur quad. moyenne: 0.626429 +/- (0.088912)
# regression lineaire:, alpha= 0.012000, erreur quad. moyenne: 0.674048 +/- (0.070248)
# regression lineaire:, alpha= 0.013000, erreur quad. moyenne: 0.612381 +/- (0.091552)
# regression lineaire:, alpha= 0.014000, erreur quad. moyenne: 0.593571 +/- (0.118149)
# regression lineaire:, alpha= 0.015000, erreur quad. moyenne: 0.626190 +/- (0.108614)
# regression lineaire:, alpha= 0.016000, erreur quad. moyenne: 0.640714 +/- (0.104363)
# regression lineaire:, alpha= 0.017000, erreur quad. moyenne: 0.598333 +/- (0.137627)
# regression lineaire:, alpha= 0.018000, erreur quad. moyenne: 0.649762 +/- (0.098102)
# regression lineaire:, alpha= 0.019000, erreur quad. moyenne: 0.678810 +/- (0.082961)
# regression lineaire:, alpha= 0.020000, erreur quad. moyenne: 0.636429 +/- (0.085304)
# regression lineaire:, alpha= 0.021000, erreur quad. moyenne: 0.602857 +/- (0.139650)
# regression lineaire:, alpha= 0.022000, erreur quad. moyenne: 0.660476 +/- (0.104676)
# regression lineaire:, alpha= 0.023000, erreur quad. moyenne: 0.716667 +/- (0.115887)
# regression lineaire:, alpha= 0.024000, erreur quad. moyenne: 0.593810 +/- (0.155825)
# regression lineaire:, alpha= 0.025000, erreur quad. moyenne: 0.621905 +/- (0.135630)
# regression lineaire:, alpha= 0.026000, erreur quad. moyenne: 0.650714 +/- (0.110657)
# regression lineaire:, alpha= 0.027000, erreur quad. moyenne: 0.621667 +/- (0.110731)
# regression lineaire:, alpha= 0.028000, erreur quad. moyenne: 0.655000 +/- (0.081653)
# regression lineaire:, alpha= 0.029000, erreur quad. moyenne: 0.626667 +/- (0.106377)
# regression lineaire:, alpha= 0.030000, erreur quad. moyenne: 0.607143 +/- (0.101714)
# regression lineaire:, alpha= 0.031000, erreur quad. moyenne: 0.674524 +/- (0.056041)
# regression lineaire:, alpha= 0.032000, erreur quad. moyenne: 0.645476 +/- (0.076816)
# regression lineaire:, alpha= 0.033000, erreur quad. moyenne: 0.641190 +/- (0.120712)
# regression lineaire:, alpha= 0.034000, erreur quad. moyenne: 0.617381 +/- (0.143972)
# regression lineaire:, alpha= 0.035000, erreur quad. moyenne: 0.650714 +/- (0.129538)
# regression lineaire:, alpha= 0.036000, erreur quad. moyenne: 0.664524 +/- (0.085160)
# regression lineaire:, alpha= 0.037000, erreur quad. moyenne: 0.645476 +/- (0.147559)
# regression lineaire:, alpha= 0.038000, erreur quad. moyenne: 0.616905 +/- (0.126958)
# regression lineaire:, alpha= 0.039000, erreur quad. moyenne: 0.607619 +/- (0.094742)
# regression lineaire:, alpha= 0.040000, erreur quad. moyenne: 0.660476 +/- (0.067882)
# regression lineaire:, alpha= 0.041000, erreur quad. moyenne: 0.635952 +/- (0.108423)
# regression lineaire:, alpha= 0.042000, erreur quad. moyenne: 0.736190 +/- (0.096002)
# regression lineaire:, alpha= 0.043000, erreur quad. moyenne: 0.683810 +/- (0.051429)
# regression lineaire:, alpha= 0.044000, erreur quad. moyenne: 0.640714 +/- (0.082523)
# regression lineaire:, alpha= 0.045000, erreur quad. moyenne: 0.660000 +/- (0.094957)
# regression lineaire:, alpha= 0.046000, erreur quad. moyenne: 0.664762 +/- (0.075208)
# regression lineaire:, alpha= 0.047000, erreur quad. moyenne: 0.664762 +/- (0.075208)
# regression lineaire:, alpha= 0.048000, erreur quad. moyenne: 0.655000 +/- (0.084384)
# regression lineaire:, alpha= 0.049000, erreur quad. moyenne: 0.683810 +/- (0.051429)
# regression lineaire:, alpha= 0.050000, erreur quad. moyenne: 0.616905 +/- (0.103326)
# regression lineaire:, alpha= 0.051000, erreur quad. moyenne: 0.645476 +/- (0.060276)
# regression lineaire:, alpha= 0.052000, erreur quad. moyenne: 0.683571 +/- (0.077872)
# regression lineaire:, alpha= 0.053000, erreur quad. moyenne: 0.679286 +/- (0.083054)
# regression lineaire:, alpha= 0.054000, erreur quad. moyenne: 0.640714 +/- (0.073821)
# regression lineaire:, alpha= 0.055000, erreur quad. moyenne: 0.660000 +/- (0.090054)
# regression lineaire:, alpha= 0.056000, erreur quad. moyenne: 0.626429 +/- (0.075085)
# regression lineaire:, alpha= 0.057000, erreur quad. moyenne: 0.655476 +/- (0.120063)
# regression lineaire:, alpha= 0.058000, erreur quad. moyenne: 0.660476 +/- (0.080137)
# regression lineaire:, alpha= 0.059000, erreur quad. moyenne: 0.669762 +/- (0.115745)
# regression lineaire:, alpha= 0.060000, erreur quad. moyenne: 0.693333 +/- (0.067047)
# regression lineaire:, alpha= 0.061000, erreur quad. moyenne: 0.660000 +/- (0.122117)
# regression lineaire:, alpha= 0.062000, erreur quad. moyenne: 0.641429 +/- (0.092436)
# regression lineaire:, alpha= 0.063000, erreur quad. moyenne: 0.645714 +/- (0.105435)
# regression lineaire:, alpha= 0.064000, erreur quad. moyenne: 0.688810 +/- (0.086452)
# regression lineaire:, alpha= 0.065000, erreur quad. moyenne: 0.612857 +/- (0.104024)
# regression lineaire:, alpha= 0.066000, erreur quad. moyenne: 0.683810 +/- (0.076286)
# regression lineaire:, alpha= 0.067000, erreur quad. moyenne: 0.674524 +/- (0.092644)
# regression lineaire:, alpha= 0.068000, erreur quad. moyenne: 0.688810 +/- (0.083788)
# regression lineaire:, alpha= 0.069000, erreur quad. moyenne: 0.592857 +/- (0.093101)
# regression lineaire:, alpha= 0.070000, erreur quad. moyenne: 0.669762 +/- (0.096516)
# regression lineaire:, alpha= 0.071000, erreur quad. moyenne: 0.616667 +/- (0.122544)
# regression lineaire:, alpha= 0.072000, erreur quad. moyenne: 0.655238 +/- (0.117015)
# regression lineaire:, alpha= 0.073000, erreur quad. moyenne: 0.631429 +/- (0.093416)
# regression lineaire:, alpha= 0.074000, erreur quad. moyenne: 0.645714 +/- (0.065680)
# regression lineaire:, alpha= 0.075000, erreur quad. moyenne: 0.683810 +/- (0.084735)
# regression lineaire:, alpha= 0.076000, erreur quad. moyenne: 0.655000 +/- (0.081653)
# regression lineaire:, alpha= 0.077000, erreur quad. moyenne: 0.669524 +/- (0.090255)
# regression lineaire:, alpha= 0.078000, erreur quad. moyenne: 0.660476 +/- (0.093218)
# regression lineaire:, alpha= 0.079000, erreur quad. moyenne: 0.679286 +/- (0.077401)
# regression lineaire:, alpha= 0.080000, erreur quad. moyenne: 0.640714 +/- (0.087847)
# regression lineaire:, alpha= 0.081000, erreur quad. moyenne: 0.669048 +/- (0.147715)
# regression lineaire:, alpha= 0.082000, erreur quad. moyenne: 0.703333 +/- (0.108129)
# regression lineaire:, alpha= 0.083000, erreur quad. moyenne: 0.645476 +/- (0.087834)
# regression lineaire:, alpha= 0.084000, erreur quad. moyenne: 0.659762 +/- (0.107320)
# regression lineaire:, alpha= 0.085000, erreur quad. moyenne: 0.584048 +/- (0.115686)
# regression lineaire:, alpha= 0.086000, erreur quad. moyenne: 0.640476 +/- (0.089373)
# regression lineaire:, alpha= 0.087000, erreur quad. moyenne: 0.669762 +/- (0.081204)
# regression lineaire:, alpha= 0.088000, erreur quad. moyenne: 0.683810 +/- (0.079202)
# regression lineaire:, alpha= 0.089000, erreur quad. moyenne: 0.679048 +/- (0.054884)
# regression lineaire:, alpha= 0.090000, erreur quad. moyenne: 0.703095 +/- (0.124422)
# regression lineaire:, alpha= 0.091000, erreur quad. moyenne: 0.683810 +/- (0.084735)
# regression lineaire:, alpha= 0.092000, erreur quad. moyenne: 0.688571 +/- (0.056029)
# regression lineaire:, alpha= 0.093000, erreur quad. moyenne: 0.669286 +/- (0.107510)
# regression lineaire:, alpha= 0.094000, erreur quad. moyenne: 0.630952 +/- (0.091132)
# regression lineaire:, alpha= 0.095000, erreur quad. moyenne: 0.626905 +/- (0.111829)
# regression lineaire:, alpha= 0.096000, erreur quad. moyenne: 0.631429 +/- (0.100434)
# regression lineaire:, alpha= 0.097000, erreur quad. moyenne: 0.617619 +/- (0.061870)
# regression lineaire:, alpha= 0.098000, erreur quad. moyenne: 0.674048 +/- (0.108340)
# regression lineaire:, alpha= 0.099000, erreur quad. moyenne: 0.664286 +/- (0.084146)
# regression lineaire:, alpha= 0.100000, erreur quad. moyenne: 0.669048 +/- (0.108823)
# regression lineaire:, alpha= 0.101000, erreur quad. moyenne: 0.655000 +/- (0.110043)
# regression lineaire:, alpha= 0.102000, erreur quad. moyenne: 0.655476 +/- (0.106021)
# regression lineaire:, alpha= 0.103000, erreur quad. moyenne: 0.659286 +/- (0.151682)
# regression lineaire:, alpha= 0.104000, erreur quad. moyenne: 0.655476 +/- (0.092300)
# regression lineaire:, alpha= 0.105000, erreur quad. moyenne: 0.612143 +/- (0.090215)
# regression lineaire:, alpha= 0.106000, erreur quad. moyenne: 0.602857 +/- (0.097595)
# regression lineaire:, alpha= 0.107000, erreur quad. moyenne: 0.669762 +/- (0.078362)
# regression lineaire:, alpha= 0.108000, erreur quad. moyenne: 0.664524 +/- (0.076757)
# regression lineaire:, alpha= 0.109000, erreur quad. moyenne: 0.650000 +/- (0.101043)
# regression lineaire:, alpha= 0.110000, erreur quad. moyenne: 0.636190 +/- (0.088914)
# regression lineaire:, alpha= 0.111000, erreur quad. moyenne: 0.655476 +/- (0.063120)
# regression lineaire:, alpha= 0.112000, erreur quad. moyenne: 0.645714 +/- (0.065680)
# regression lineaire:, alpha= 0.113000, erreur quad. moyenne: 0.660238 +/- (0.081009)
# regression lineaire:, alpha= 0.114000, erreur quad. moyenne: 0.665000 +/- (0.070807)
# regression lineaire:, alpha= 0.115000, erreur quad. moyenne: 0.665476 +/- (0.098810)
# regression lineaire:, alpha= 0.116000, erreur quad. moyenne: 0.640714 +/- (0.085226)
# regression lineaire:, alpha= 0.117000, erreur quad. moyenne: 0.635714 +/- (0.105436)
# regression lineaire:, alpha= 0.118000, erreur quad. moyenne: 0.635714 +/- (0.096451)
# regression lineaire:, alpha= 0.119000, erreur quad. moyenne: 0.650000 +/- (0.078282)
# regression lineaire:, alpha= 0.120000, erreur quad. moyenne: 0.635952 +/- (0.092634)
# regression lineaire:, alpha= 0.121000, erreur quad. moyenne: 0.635714 +/- (0.119547)
# regression lineaire:, alpha= 0.122000, erreur quad. moyenne: 0.640714 +/- (0.087847)
# regression lineaire:, alpha= 0.123000, erreur quad. moyenne: 0.635952 +/- (0.136229)
# regression lineaire:, alpha= 0.124000, erreur quad. moyenne: 0.645476 +/- (0.063927)
# regression lineaire:, alpha= 0.125000, erreur quad. moyenne: 0.665000 +/- (0.085330)
# regression lineaire:, alpha= 0.126000, erreur quad. moyenne: 0.655000 +/- (0.081653)
# regression lineaire:, alpha= 0.127000, erreur quad. moyenne: 0.669048 +/- (0.114904)
# regression lineaire:, alpha= 0.128000, erreur quad. moyenne: 0.684048 +/- (0.080799)
# regression lineaire:, alpha= 0.129000, erreur quad. moyenne: 0.664762 +/- (0.089016)
# regression lineaire:, alpha= 0.130000, erreur quad. moyenne: 0.684286 +/- (0.060461)
# regression lineaire:, alpha= 0.131000, erreur quad. moyenne: 0.669286 +/- (0.091563)
# regression lineaire:, alpha= 0.132000, erreur quad. moyenne: 0.636190 +/- (0.088914)
# regression lineaire:, alpha= 0.133000, erreur quad. moyenne: 0.583333 +/- (0.079147)
# regression lineaire:, alpha= 0.134000, erreur quad. moyenne: 0.607143 +/- (0.070026)
# regression lineaire:, alpha= 0.135000, erreur quad. moyenne: 0.621429 +/- (0.094311)
# regression lineaire:, alpha= 0.136000, erreur quad. moyenne: 0.626429 +/- (0.065400)
# regression lineaire:, alpha= 0.137000, erreur quad. moyenne: 0.635714 +/- (0.078282)
# regression lineaire:, alpha= 0.138000, erreur quad. moyenne: 0.660238 +/- (0.045025)
# regression lineaire:, alpha= 0.139000, erreur quad. moyenne: 0.697857 +/- (0.093693)
# regression lineaire:, alpha= 0.140000, erreur quad. moyenne: 0.617143 +/- (0.079887)
# regression lineaire:, alpha= 0.141000, erreur quad. moyenne: 0.655238 +/- (0.077348)
# regression lineaire:, alpha= 0.142000, erreur quad. moyenne: 0.645952 +/- (0.085489)
# regression lineaire:, alpha= 0.143000, erreur quad. moyenne: 0.636667 +/- (0.099341)
# regression lineaire:, alpha= 0.144000, erreur quad. moyenne: 0.641190 +/- (0.067780)
# regression lineaire:, alpha= 0.145000, erreur quad. moyenne: 0.679048 +/- (0.086876)
# regression lineaire:, alpha= 0.146000, erreur quad. moyenne: 0.635714 +/- (0.081127)
# regression lineaire:, alpha= 0.147000, erreur quad. moyenne: 0.698333 +/- (0.096068)
# regression lineaire:, alpha= 0.148000, erreur quad. moyenne: 0.674524 +/- (0.076562)
# regression lineaire:, alpha= 0.149000, erreur quad. moyenne: 0.650000 +/- (0.107565)
# regression lineaire:, alpha= 0.150000, erreur quad. moyenne: 0.665000 +/- (0.079839)
# regression lineaire:, alpha= 0.151000, erreur quad. moyenne: 0.640952 +/- (0.078310)
# regression lineaire:, alpha= 0.152000, erreur quad. moyenne: 0.626667 +/- (0.112591)
# regression lineaire:, alpha= 0.153000, erreur quad. moyenne: 0.645714 +/- (0.128681)
# regression lineaire:, alpha= 0.154000, erreur quad. moyenne: 0.693095 +/- (0.078133)
# regression lineaire:, alpha= 0.155000, erreur quad. moyenne: 0.621905 +/- (0.058562)
# regression lineaire:, alpha= 0.156000, erreur quad. moyenne: 0.616905 +/- (0.081207)
# regression lineaire:, alpha= 0.157000, erreur quad. moyenne: 0.650238 +/- (0.097372)
# regression lineaire:, alpha= 0.158000, erreur quad. moyenne: 0.669524 +/- (0.056190)
# regression lineaire:, alpha= 0.159000, erreur quad. moyenne: 0.640476 +/- (0.084146)
# regression lineaire:, alpha= 0.160000, erreur quad. moyenne: 0.625952 +/- (0.087017)
# regression lineaire:, alpha= 0.161000, erreur quad. moyenne: 0.659524 +/- (0.144455)
# regression lineaire:, alpha= 0.162000, erreur quad. moyenne: 0.678810 +/- (0.085651)
# regression lineaire:, alpha= 0.163000, erreur quad. moyenne: 0.616667 +/- (0.093101)
# regression lineaire:, alpha= 0.164000, erreur quad. moyenne: 0.659524 +/- (0.106506)
# regression lineaire:, alpha= 0.165000, erreur quad. moyenne: 0.616429 +/- (0.118161)
# regression lineaire:, alpha= 0.166000, erreur quad. moyenne: 0.631905 +/- (0.101196)
# regression lineaire:, alpha= 0.167000, erreur quad. moyenne: 0.631190 +/- (0.119951)
# regression lineaire:, alpha= 0.168000, erreur quad. moyenne: 0.626429 +/- (0.100861)
# regression lineaire:, alpha= 0.169000, erreur quad. moyenne: 0.655476 +/- (0.066616)
# regression lineaire:, alpha= 0.170000, erreur quad. moyenne: 0.626667 +/- (0.104224)
# regression lineaire:, alpha= 0.171000, erreur quad. moyenne: 0.612381 +/- (0.096379)
# regression lineaire:, alpha= 0.172000, erreur quad. moyenne: 0.645714 +/- (0.086536)
# regression lineaire:, alpha= 0.173000, erreur quad. moyenne: 0.626667 +/- (0.079545)
# regression lineaire:, alpha= 0.174000, erreur quad. moyenne: 0.635714 +/- (0.107565)
# regression lineaire:, alpha= 0.175000, erreur quad. moyenne: 0.635476 +/- (0.083043)
# regression lineaire:, alpha= 0.176000, erreur quad. moyenne: 0.664524 +/- (0.085160)
# regression lineaire:, alpha= 0.177000, erreur quad. moyenne: 0.640952 +/- (0.078310)
# regression lineaire:, alpha= 0.178000, erreur quad. moyenne: 0.616667 +/- (0.104572)
# regression lineaire:, alpha= 0.179000, erreur quad. moyenne: 0.650476 +/- (0.117421)
# regression lineaire:, alpha= 0.180000, erreur quad. moyenne: 0.635476 +/- (0.106917)
# regression lineaire:, alpha= 0.181000, erreur quad. moyenne: 0.626429 +/- (0.115531)
# regression lineaire:, alpha= 0.182000, erreur quad. moyenne: 0.655238 +/- (0.088300)
# regression lineaire:, alpha= 0.183000, erreur quad. moyenne: 0.597857 +/- (0.091748)
# regression lineaire:, alpha= 0.184000, erreur quad. moyenne: 0.645000 +/- (0.091141)
# regression lineaire:, alpha= 0.185000, erreur quad. moyenne: 0.688333 +/- (0.086415)
# regression lineaire:, alpha= 0.186000, erreur quad. moyenne: 0.597857 +/- (0.078423)
# regression lineaire:, alpha= 0.187000, erreur quad. moyenne: 0.640952 +/- (0.069079)
# regression lineaire:, alpha= 0.188000, erreur quad. moyenne: 0.588333 +/- (0.115610)
# regression lineaire:, alpha= 0.189000, erreur quad. moyenne: 0.597857 +/- (0.103370)
# regression lineaire:, alpha= 0.190000, erreur quad. moyenne: 0.602619 +/- (0.096318)
# regression lineaire:, alpha= 0.191000, erreur quad. moyenne: 0.636190 +/- (0.088914)
# regression lineaire:, alpha= 0.192000, erreur quad. moyenne: 0.616667 +/- (0.093101)
# regression lineaire:, alpha= 0.193000, erreur quad. moyenne: 0.626190 +/- (0.087837)
# regression lineaire:, alpha= 0.194000, erreur quad. moyenne: 0.621667 +/- (0.076890)
# regression lineaire:, alpha= 0.195000, erreur quad. moyenne: 0.631429 +/- (0.088428)
# regression lineaire:, alpha= 0.196000, erreur quad. moyenne: 0.645714 +/- (0.086536)
# regression lineaire:, alpha= 0.197000, erreur quad. moyenne: 0.645238 +/- (0.109860)
# regression lineaire:, alpha= 0.198000, erreur quad. moyenne: 0.641190 +/- (0.095547)
# regression lineaire:, alpha= 0.199000, erreur quad. moyenne: 0.554524 +/- (0.100161)
# regression lineaire:, alpha= 0.200000, erreur quad. moyenne: 0.655238 +/- (0.098035)
# regression lineaire:, alpha= 0.201000, erreur quad. moyenne: 0.616905 +/- (0.096518)
# regression lineaire:, alpha= 0.202000, erreur quad. moyenne: 0.621429 +/- (0.058757)
# regression lineaire:, alpha= 0.203000, erreur quad. moyenne: 0.588333 +/- (0.068912)
# regression lineaire:, alpha= 0.204000, erreur quad. moyenne: 0.645476 +/- (0.070666)
# regression lineaire:, alpha= 0.205000, erreur quad. moyenne: 0.617381 +/- (0.134190)
# regression lineaire:, alpha= 0.206000, erreur quad. moyenne: 0.607143 +/- (0.099460)
# regression lineaire:, alpha= 0.207000, erreur quad. moyenne: 0.621429 +/- (0.096685)
# regression lineaire:, alpha= 0.208000, erreur quad. moyenne: 0.635714 +/- (0.119547)
# regression lineaire:, alpha= 0.209000, erreur quad. moyenne: 0.630952 +/- (0.111295)
# regression lineaire:, alpha= 0.210000, erreur quad. moyenne: 0.593333 +/- (0.116879)
# regression lineaire:, alpha= 0.211000, erreur quad. moyenne: 0.640714 +/- (0.129566)
# regression lineaire:, alpha= 0.212000, erreur quad. moyenne: 0.597619 +/- (0.112913)
# regression lineaire:, alpha= 0.213000, erreur quad. moyenne: 0.640476 +/- (0.115887)
# regression lineaire:, alpha= 0.214000, erreur quad. moyenne: 0.650238 +/- (0.101923)
# regression lineaire:, alpha= 0.215000, erreur quad. moyenne: 0.645000 +/- (0.091141)
# regression lineaire:, alpha= 0.216000, erreur quad. moyenne: 0.607619 +/- (0.123795)
# regression lineaire:, alpha= 0.217000, erreur quad. moyenne: 0.645714 +/- (0.140475)
# regression lineaire:, alpha= 0.218000, erreur quad. moyenne: 0.525952 +/- (0.118935)
# regression lineaire:, alpha= 0.219000, erreur quad. moyenne: 0.569048 +/- (0.123466)
# regression lineaire:, alpha= 0.220000, erreur quad. moyenne: 0.621190 +/- (0.095929)
# regression lineaire:, alpha= 0.221000, erreur quad. moyenne: 0.587619 +/- (0.126710)
# regression lineaire:, alpha= 0.222000, erreur quad. moyenne: 0.631429 +/- (0.143241)
# regression lineaire:, alpha= 0.223000, erreur quad. moyenne: 0.598333 +/- (0.099352)
# regression lineaire:, alpha= 0.224000, erreur quad. moyenne: 0.598571 +/- (0.146803)
# regression lineaire:, alpha= 0.225000, erreur quad. moyenne: 0.593333 +/- (0.102402)
# regression lineaire:, alpha= 0.226000, erreur quad. moyenne: 0.655238 +/- (0.064566)
# regression lineaire:, alpha= 0.227000, erreur quad. moyenne: 0.602143 +/- (0.117940)
# regression lineaire:, alpha= 0.228000, erreur quad. moyenne: 0.625952 +/- (0.087017)
# regression lineaire:, alpha= 0.229000, erreur quad. moyenne: 0.616905 +/- (0.083953)
# regression lineaire:, alpha= 0.230000, erreur quad. moyenne: 0.588571 +/- (0.085269)
# regression lineaire:, alpha= 0.231000, erreur quad. moyenne: 0.612619 +/- (0.095524)
# regression lineaire:, alpha= 0.232000, erreur quad. moyenne: 0.621667 +/- (0.087898)
# regression lineaire:, alpha= 0.233000, erreur quad. moyenne: 0.531429 +/- (0.104658)
# regression lineaire:, alpha= 0.234000, erreur quad. moyenne: 0.621429 +/- (0.107776)
# regression lineaire:, alpha= 0.235000, erreur quad. moyenne: 0.626190 +/- (0.120491)
# regression lineaire:, alpha= 0.236000, erreur quad. moyenne: 0.601905 +/- (0.151234)
# regression lineaire:, alpha= 0.237000, erreur quad. moyenne: 0.649762 +/- (0.135059)
# regression lineaire:, alpha= 0.238000, erreur quad. moyenne: 0.588333 +/- (0.128609)
# regression lineaire:, alpha= 0.239000, erreur quad. moyenne: 0.611667 +/- (0.147820)
# regression lineaire:, alpha= 0.240000, erreur quad. moyenne: 0.564286 +/- (0.070671)
# regression lineaire:, alpha= 0.241000, erreur quad. moyenne: 0.603095 +/- (0.117899)
# regression lineaire:, alpha= 0.242000, erreur quad. moyenne: 0.598095 +/- (0.153732)
# regression lineaire:, alpha= 0.243000, erreur quad. moyenne: 0.583333 +/- (0.110272)
# regression lineaire:, alpha= 0.244000, erreur quad. moyenne: 0.588571 +/- (0.118632)
# regression lineaire:, alpha= 0.245000, erreur quad. moyenne: 0.626190 +/- (0.126011)
# regression lineaire:, alpha= 0.246000, erreur quad. moyenne: 0.635714 +/- (0.094070)
# regression lineaire:, alpha= 0.247000, erreur quad. moyenne: 0.626667 +/- (0.076642)
# regression lineaire:, alpha= 0.248000, erreur quad. moyenne: 0.545714 +/- (0.135897)
# regression lineaire:, alpha= 0.249000, erreur quad. moyenne: 0.569048 +/- (0.103482)
# regression lineaire:, alpha= 0.250000, erreur quad. moyenne: 0.630952 +/- (0.133525)
# regression lineaire:, alpha= 0.251000, erreur quad. moyenne: 0.598095 +/- (0.090631)
# regression lineaire:, alpha= 0.252000, erreur quad. moyenne: 0.569048 +/- (0.125289)
# regression lineaire:, alpha= 0.253000, erreur quad. moyenne: 0.564286 +/- (0.118594)
# regression lineaire:, alpha= 0.254000, erreur quad. moyenne: 0.583095 +/- (0.100905)
# regression lineaire:, alpha= 0.255000, erreur quad. moyenne: 0.635714 +/- (0.115691)
# regression lineaire:, alpha= 0.256000, erreur quad. moyenne: 0.630714 +/- (0.076787)
# regression lineaire:, alpha= 0.257000, erreur quad. moyenne: 0.617143 +/- (0.136480)
# regression lineaire:, alpha= 0.258000, erreur quad. moyenne: 0.626190 +/- (0.085217)
# regression lineaire:, alpha= 0.259000, erreur quad. moyenne: 0.631667 +/- (0.094904)
# regression lineaire:, alpha= 0.260000, erreur quad. moyenne: 0.564524 +/- (0.081081)
# regression lineaire:, alpha= 0.261000, erreur quad. moyenne: 0.630952 +/- (0.138526)
# regression lineaire:, alpha= 0.262000, erreur quad. moyenne: 0.569048 +/- (0.113913)
# regression lineaire:, alpha= 0.263000, erreur quad. moyenne: 0.554524 +/- (0.144626)
# regression lineaire:, alpha= 0.264000, erreur quad. moyenne: 0.616905 +/- (0.096518)
# regression lineaire:, alpha= 0.265000, erreur quad. moyenne: 0.602143 +/- (0.099137)
# regression lineaire:, alpha= 0.266000, erreur quad. moyenne: 0.564762 +/- (0.106654)
# regression lineaire:, alpha= 0.267000, erreur quad. moyenne: 0.583333 +/- (0.087320)
# regression lineaire:, alpha= 0.268000, erreur quad. moyenne: 0.626429 +/- (0.054006)
# regression lineaire:, alpha= 0.269000, erreur quad. moyenne: 0.598095 +/- (0.108822)
# regression lineaire:, alpha= 0.270000, erreur quad. moyenne: 0.592857 +/- (0.124381)
# regression lineaire:, alpha= 0.271000, erreur quad. moyenne: 0.597619 +/- (0.112913)
# regression lineaire:, alpha= 0.272000, erreur quad. moyenne: 0.592857 +/- (0.080001)
# regression lineaire:, alpha= 0.273000, erreur quad. moyenne: 0.535714 +/- (0.152548)
# regression lineaire:, alpha= 0.274000, erreur quad. moyenne: 0.583095 +/- (0.109526)
# regression lineaire:, alpha= 0.275000, erreur quad. moyenne: 0.611429 +/- (0.110558)
# regression lineaire:, alpha= 0.276000, erreur quad. moyenne: 0.607143 +/- (0.097153)
# regression lineaire:, alpha= 0.277000, erreur quad. moyenne: 0.607143 +/- (0.132673)
# regression lineaire:, alpha= 0.278000, erreur quad. moyenne: 0.578810 +/- (0.097546)
# regression lineaire:, alpha= 0.279000, erreur quad. moyenne: 0.554524 +/- (0.144626)
# regression lineaire:, alpha= 0.280000, erreur quad. moyenne: 0.597381 +/- (0.148715)
# regression lineaire:, alpha= 0.281000, erreur quad. moyenne: 0.612381 +/- (0.068947)
# regression lineaire:, alpha= 0.282000, erreur quad. moyenne: 0.569048 +/- (0.105651)
# regression lineaire:, alpha= 0.283000, erreur quad. moyenne: 0.587857 +/- (0.094416)
# regression lineaire:, alpha= 0.284000, erreur quad. moyenne: 0.626190 +/- (0.079717)
# regression lineaire:, alpha= 0.285000, erreur quad. moyenne: 0.617381 +/- (0.130766)
# regression lineaire:, alpha= 0.286000, erreur quad. moyenne: 0.545476 +/- (0.118792)
# regression lineaire:, alpha= 0.287000, erreur quad. moyenne: 0.569048 +/- (0.127086)
# regression lineaire:, alpha= 0.288000, erreur quad. moyenne: 0.617381 +/- (0.143972)
# regression lineaire:, alpha= 0.289000, erreur quad. moyenne: 0.635714 +/- (0.111702)
# regression lineaire:, alpha= 0.290000, erreur quad. moyenne: 0.555000 +/- (0.095253)
# regression lineaire:, alpha= 0.291000, erreur quad. moyenne: 0.583333 +/- (0.112309)
# regression lineaire:, alpha= 0.292000, erreur quad. moyenne: 0.593095 +/- (0.081277)
# regression lineaire:, alpha= 0.293000, erreur quad. moyenne: 0.578571 +/- (0.103263)
# regression lineaire:, alpha= 0.294000, erreur quad. moyenne: 0.587857 +/- (0.105745)
# regression lineaire:, alpha= 0.295000, erreur quad. moyenne: 0.645238 +/- (0.084146)
# regression lineaire:, alpha= 0.296000, erreur quad. moyenne: 0.584048 +/- (0.089113)
# regression lineaire:, alpha= 0.297000, erreur quad. moyenne: 0.621667 +/- (0.104407)
# regression lineaire:, alpha= 0.298000, erreur quad. moyenne: 0.597857 +/- (0.130516)
# regression lineaire:, alpha= 0.299000, erreur quad. moyenne: 0.640476 +/- (0.089373)
# regression lineaire:, alpha= 0.300000, erreur quad. moyenne: 0.569048 +/- (0.078571)
# regression lineaire:, alpha= 0.301000, erreur quad. moyenne: 0.597857 +/- (0.128767)
# regression lineaire:, alpha= 0.302000, erreur quad. moyenne: 0.626190 +/- (0.102159)
# regression lineaire:, alpha= 0.303000, erreur quad. moyenne: 0.597857 +/- (0.140555)
# regression lineaire:, alpha= 0.304000, erreur quad. moyenne: 0.549762 +/- (0.178449)
# regression lineaire:, alpha= 0.305000, erreur quad. moyenne: 0.588571 +/- (0.118632)
# regression lineaire:, alpha= 0.306000, erreur quad. moyenne: 0.607619 +/- (0.097106)
# regression lineaire:, alpha= 0.307000, erreur quad. moyenne: 0.569048 +/- (0.075630)
# regression lineaire:, alpha= 0.308000, erreur quad. moyenne: 0.607143 +/- (0.094791)
# regression lineaire:, alpha= 0.309000, erreur quad. moyenne: 0.593333 +/- (0.095528)
# regression lineaire:, alpha= 0.310000, erreur quad. moyenne: 0.621429 +/- (0.127086)
# regression lineaire:, alpha= 0.311000, erreur quad. moyenne: 0.573810 +/- (0.097851)
# regression lineaire:, alpha= 0.312000, erreur quad. moyenne: 0.583333 +/- (0.084683)
# regression lineaire:, alpha= 0.313000, erreur quad. moyenne: 0.640952 +/- (0.081154)
# regression lineaire:, alpha= 0.314000, erreur quad. moyenne: 0.588810 +/- (0.078810)
# regression lineaire:, alpha= 0.315000, erreur quad. moyenne: 0.606905 +/- (0.100962)
# regression lineaire:, alpha= 0.316000, erreur quad. moyenne: 0.597619 +/- (0.120679)
# regression lineaire:, alpha= 0.317000, erreur quad. moyenne: 0.631190 +/- (0.069746)
# regression lineaire:, alpha= 0.318000, erreur quad. moyenne: 0.578571 +/- (0.140476)
# regression lineaire:, alpha= 0.319000, erreur quad. moyenne: 0.564286 +/- (0.129560)
# regression lineaire:, alpha= 0.320000, erreur quad. moyenne: 0.611905 +/- (0.117634)
# regression lineaire:, alpha= 0.321000, erreur quad. moyenne: 0.588333 +/- (0.146727)
# regression lineaire:, alpha= 0.322000, erreur quad. moyenne: 0.511905 +/- (0.125650)
# regression lineaire:, alpha= 0.323000, erreur quad. moyenne: 0.607143 +/- (0.106079)
# regression lineaire:, alpha= 0.324000, erreur quad. moyenne: 0.593095 +/- (0.111811)
# regression lineaire:, alpha= 0.325000, erreur quad. moyenne: 0.559524 +/- (0.109239)
# regression lineaire:, alpha= 0.326000, erreur quad. moyenne: 0.545238 +/- (0.125289)
# regression lineaire:, alpha= 0.327000, erreur quad. moyenne: 0.588571 +/- (0.108655)
# regression lineaire:, alpha= 0.328000, erreur quad. moyenne: 0.545476 +/- (0.150759)
# regression lineaire:, alpha= 0.329000, erreur quad. moyenne: 0.626190 +/- (0.134708)
# regression lineaire:, alpha= 0.330000, erreur quad. moyenne: 0.555238 +/- (0.127067)
# regression lineaire:, alpha= 0.331000, erreur quad. moyenne: 0.645476 +/- (0.110679)
# regression lineaire:, alpha= 0.332000, erreur quad. moyenne: 0.612381 +/- (0.075238)
# regression lineaire:, alpha= 0.333000, erreur quad. moyenne: 0.597857 +/- (0.091748)
# regression lineaire:, alpha= 0.334000, erreur quad. moyenne: 0.583333 +/- (0.101714)
# regression lineaire:, alpha= 0.335000, erreur quad. moyenne: 0.568571 +/- (0.142797)
# regression lineaire:, alpha= 0.336000, erreur quad. moyenne: 0.607143 +/- (0.121988)
# regression lineaire:, alpha= 0.337000, erreur quad. moyenne: 0.588095 +/- (0.079717)
# regression lineaire:, alpha= 0.338000, erreur quad. moyenne: 0.569048 +/- (0.078571)
# regression lineaire:, alpha= 0.339000, erreur quad. moyenne: 0.630952 +/- (0.162621)
# regression lineaire:, alpha= 0.340000, erreur quad. moyenne: 0.578571 +/- (0.125108)
# regression lineaire:, alpha= 0.341000, erreur quad. moyenne: 0.569048 +/- (0.117827)
# regression lineaire:, alpha= 0.342000, erreur quad. moyenne: 0.545476 +/- (0.120686)
# regression lineaire:, alpha= 0.343000, erreur quad. moyenne: 0.597381 +/- (0.092254)
# regression lineaire:, alpha= 0.344000, erreur quad. moyenne: 0.611667 +/- (0.136661)
# regression lineaire:, alpha= 0.345000, erreur quad. moyenne: 0.535238 +/- (0.123428)
# regression lineaire:, alpha= 0.346000, erreur quad. moyenne: 0.564048 +/- (0.109898)
# regression lineaire:, alpha= 0.347000, erreur quad. moyenne: 0.540714 +/- (0.124214)
# regression lineaire:, alpha= 0.348000, erreur quad. moyenne: 0.564286 +/- (0.073810)
# regression lineaire:, alpha= 0.349000, erreur quad. moyenne: 0.583571 +/- (0.128264)
# regression lineaire:, alpha= 0.350000, erreur quad. moyenne: 0.598333 +/- (0.147181)
# regression lineaire:, alpha= 0.351000, erreur quad. moyenne: 0.564286 +/- (0.122359)
# regression lineaire:, alpha= 0.352000, erreur quad. moyenne: 0.621667 +/- (0.114753)
# regression lineaire:, alpha= 0.353000, erreur quad. moyenne: 0.607381 +/- (0.135109)
# regression lineaire:, alpha= 0.354000, erreur quad. moyenne: 0.530714 +/- (0.103447)
# regression lineaire:, alpha= 0.355000, erreur quad. moyenne: 0.530952 +/- (0.120491)
# regression lineaire:, alpha= 0.356000, erreur quad. moyenne: 0.602619 +/- (0.105315)
# regression lineaire:, alpha= 0.357000, erreur quad. moyenne: 0.550476 +/- (0.107985)
# regression lineaire:, alpha= 0.358000, erreur quad. moyenne: 0.559762 +/- (0.150285)
# regression lineaire:, alpha= 0.359000, erreur quad. moyenne: 0.611667 +/- (0.100297)
# regression lineaire:, alpha= 0.360000, erreur quad. moyenne: 0.564524 +/- (0.146766)
# regression lineaire:, alpha= 0.361000, erreur quad. moyenne: 0.596905 +/- (0.121181)
# regression lineaire:, alpha= 0.362000, erreur quad. moyenne: 0.530714 +/- (0.109826)
# regression lineaire:, alpha= 0.363000, erreur quad. moyenne: 0.569048 +/- (0.167159)
# regression lineaire:, alpha= 0.364000, erreur quad. moyenne: 0.612381 +/- (0.123226)
# regression lineaire:, alpha= 0.365000, erreur quad. moyenne: 0.578095 +/- (0.112450)
# regression lineaire:, alpha= 0.366000, erreur quad. moyenne: 0.597857 +/- (0.096565)
# regression lineaire:, alpha= 0.367000, erreur quad. moyenne: 0.655000 +/- (0.087030)
# regression lineaire:, alpha= 0.368000, erreur quad. moyenne: 0.569048 +/- (0.111905)
# regression lineaire:, alpha= 0.369000, erreur quad. moyenne: 0.516905 +/- (0.095348)
# regression lineaire:, alpha= 0.370000, erreur quad. moyenne: 0.540476 +/- (0.098774)
# regression lineaire:, alpha= 0.371000, erreur quad. moyenne: 0.573810 +/- (0.165112)
# regression lineaire:, alpha= 0.372000, erreur quad. moyenne: 0.593095 +/- (0.113821)
# regression lineaire:, alpha= 0.373000, erreur quad. moyenne: 0.597857 +/- (0.117728)
# regression lineaire:, alpha= 0.374000, erreur quad. moyenne: 0.607619 +/- (0.089827)
# regression lineaire:, alpha= 0.375000, erreur quad. moyenne: 0.597619 +/- (0.095506)
# regression lineaire:, alpha= 0.376000, erreur quad. moyenne: 0.578810 +/- (0.102090)
# regression lineaire:, alpha= 0.377000, erreur quad. moyenne: 0.611667 +/- (0.128096)
# regression lineaire:, alpha= 0.378000, erreur quad. moyenne: 0.583333 +/- (0.136048)
# regression lineaire:, alpha= 0.379000, erreur quad. moyenne: 0.607143 +/- (0.136048)
# regression lineaire:, alpha= 0.380000, erreur quad. moyenne: 0.574048 +/- (0.098943)
# regression lineaire:, alpha= 0.381000, erreur quad. moyenne: 0.616667 +/- (0.122544)
# regression lineaire:, alpha= 0.382000, erreur quad. moyenne: 0.626429 +/- (0.113551)
# regression lineaire:, alpha= 0.383000, erreur quad. moyenne: 0.650238 +/- (0.104124)
# regression lineaire:, alpha= 0.384000, erreur quad. moyenne: 0.626667 +/- (0.090230)
# regression lineaire:, alpha= 0.385000, erreur quad. moyenne: 0.550000 +/- (0.164424)
# regression lineaire:, alpha= 0.386000, erreur quad. moyenne: 0.611905 +/- (0.096451)
# regression lineaire:, alpha= 0.387000, erreur quad. moyenne: 0.621429 +/- (0.134033)
# regression lineaire:, alpha= 0.388000, erreur quad. moyenne: 0.568810 +/- (0.088413)
# regression lineaire:, alpha= 0.389000, erreur quad. moyenne: 0.578333 +/- (0.082879)
# regression lineaire:, alpha= 0.390000, erreur quad. moyenne: 0.559524 +/- (0.165386)
# regression lineaire:, alpha= 0.391000, erreur quad. moyenne: 0.587619 +/- (0.131969)
# regression lineaire:, alpha= 0.392000, erreur quad. moyenne: 0.583571 +/- (0.113242)
# regression lineaire:, alpha= 0.393000, erreur quad. moyenne: 0.564524 +/- (0.105401)
# regression lineaire:, alpha= 0.394000, erreur quad. moyenne: 0.640714 +/- (0.087847)
# regression lineaire:, alpha= 0.395000, erreur quad. moyenne: 0.592619 +/- (0.110166)
# regression lineaire:, alpha= 0.396000, erreur quad. moyenne: 0.592857 +/- (0.138198)
# regression lineaire:, alpha= 0.397000, erreur quad. moyenne: 0.621667 +/- (0.124241)
# regression lineaire:, alpha= 0.398000, erreur quad. moyenne: 0.650000 +/- (0.135547)
# regression lineaire:, alpha= 0.399000, erreur quad. moyenne: 0.597381 +/- (0.135971)

# %%
#plt.figure(1, figsize=(8, 8))
plt.plot(alphaVal,score_cv_l)

# %%
score_v2 = score_cv_l.index(max(score_cv_l))
alphaWithMaxScore = alphaVal[score_v2]
monScoreV2 = max(score_cv_l)
print("score = ", monScoreV2,  " alpha val = ", alphaWithMaxScore)
# Out:
# score =  73.61904761904762  alpha val =  0.041999999999999975

# %%
#TODO: Une boucle kfold qui optimise en même temps 
# Standardisation ou Normalisation ?
